# %% [markdown]
# # Processamento do Dataset
#
# ## Função para ler os dados do Dataset e processar
#
# - Substitui dados vazios da coluna Levy(Taxas) pela media
# - Aplica um processamento de texto para remover o texto km da coluna Mileahe(Milhas)
# - Extrai apenas o valor do volume do motor
# - Remove colunas desnecessarias ou dificeis de processar como ID e Model
# - Remove os valores muito fora da media das colunas numericas
#
# ### Aplica uma normaliçao numerica
#
# Utilizado a funçao log1p (log(1 + x)) para preservars valores 0 e normalizar os dados,
# dessa forma, muito comum quando os dados são muito assimetricos, facilita o processamento com a IA.
#
# Apos isso, para reverter os dados ao estado original, usei a funçao expm1 ( exp(x) - 1 )

# %%
import pandas as pd
import numpy as np

def process_data():
    data = pd.read_csv("./car_price_prediction.csv", sep=",")

    data['Levy'] = pd.to_numeric(data['Levy'], errors='coerce')
    levy_med = data['Levy'].median()
    data['Levy'].fillna(levy_med, inplace=True)

    data['Mileage'] = data['Mileage'].str.replace(' km', '', regex=False).astype(float)

    data['Engine volume'] = data['Engine volume'].str.extract(r'(\d+\.?\d*)').astype(float)

    data = data.drop(columns=['ID', 'Model'])

    num_columns = ['Price', 'Levy', 'Mileage', 'Engine volume']
    for col in num_columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        data = data[~((data[col] < lower_bound) | (data[col] > upper_bound))]


    data['Price'] = np.log1p(data['Price']) 
    data['Mileage'] = np.log1p(data['Mileage'])
    data['Levy'] = np.log1p(data['Levy'])

    y = data['Price']
    x = data.drop(columns=["Price"])

    return x, y

# %% [markdown]
# # Funçao de build do modelo
#
# ## Constroi as camadas de neuronios e aplica as funções matematicas
#
# 1. Camada de Input(entrada) - 64 neuronios
# 2. Camada escondida - 32 neuronios
# 3. Camada escondida - 16 neuronios
# 4. Cama escondida - 8 neuronios
# 5. Camada de saida
#
# ### Funçoes adicionais
#
# - Nas camadas é aplicado o L2 regularization. Altera a penalidade da funçao de perda, para que a Ia
# não dependa muito de pesos muito altos.
#
# - Dropout: Aplicado entre as Layers para ignorar uma porcentagem dos neuronios, tambem ajuda a IA
# a não depender muito de neuronios especificos.
#
# - BatchNormalization: normaliza os outputs das camadas para garantir que eles tenham uma media de 0 e um desvio
# padrão de 1, o que ajuda a encontrar padrões mais rapido

# %%
from keras.api.models import Sequential
from keras.api.layers import Dense, BatchNormalization, Dropout
from keras.api.optimizers import Adam
from keras.api.regularizers import l2


def build_model(dimension, func='relu', eta=0.001):
    model = Sequential([
        Dense(64, activation=func, input_dim=dimension, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.2),

        Dense(16, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.1),

        Dense(8, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.03),

        Dense(1)
    ])

    optimizer = Adam(learning_rate=eta)
    model.compile(optimizer=optimizer, loss='huber', metrics=['mae'])

    return model

# %% [markdown]
# # Função de Treinamento do Modelo
#
# ## Pré-processamento dos Dados
# - A função começa dividindo o conjunto de dados em conjuntos de treino e teste, com 80% dos dados para treinamento e 20% para teste.
#
# #### Transformadores e Escaladores
# - Para as variáveis numéricas, a transformação `StandardScaler` é aplicada para normalizar os dados, removendo a média e escalando para que a variância seja 1.
# - Para as variaveis categoricas, `OneHotEncoder` cria colunas binárias para representar cada categoria
#
# ---
#
# ## Construção do Modelo
# **Callbacks do Keras utilizdos para melhorar o treinamento**:
#    - **EarlyStopping**: Para evitar o overfitting, é aplicado um monitoramento do `val_loss`, que interrompe o treinamento caso a perda de validação não melhore após 15 épocas.
#    - **ReduceLROnPlateau**: Reduz a taxa de aprendizado se a perda de validação não melhorar após 5 épocas, ajustando dinamicamente a taxa de aprendizado.
#
# ---
#
# ## Avaliação do Modelo
#
# **Métricas de Performance**:
#    - **Erro Absoluto Médio (MAE)**: Mede a diferença média entre o preço real e o preço previsto, dando uma ideia do erro médio do modelo.
#    - **Erro Quadrático Médio (MSE)**: Penaliza erros maiores, pois eleva os erros ao quadrado.
#    - **Raiz do Erro Quadrático Médio (RMSE)**: A raiz quadrada do MSE, traz o erro de volta a escala dos preçoes.
#    - **Coeficiente de Determinação (R²)**: Mede a proporção da variabilidade do preço. Valores mais próximos de 1 indicando bons resultados.
#
# ---
#
# ## Visualização dos Resultados
#
# 1. **Curvas de Perda (Loss)**:
#    - A evolução da perda durante o treinamento e validação é plotada para acompanhar o progresso do modelo e verificar se está ocorrendo overfitting.
#
# 2. **Gráfico de Preço Real vs. Preço Predito**:
#    - Grafico de disperção com uma linha vermelha indicando o valor correto, e o que foi chutado pela IA

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.api.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer

def train_model():
    x, y = process_data()

    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.2, random_state=42
    )

    numeric_features = [
        'Levy', 'Prod. year', 'Engine volume', 
        'Mileage', 'Cylinders', 'Airbags', 'Doors'
    ]
    
    categorical_features = [
        'Manufacturer', 'Category', 'Leather interior',
        'Fuel type', 'Gear box type', 'Drive wheels',
        'Wheel', 'Color'
    ]

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), numeric_features),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])
    
    x_train_processed = preprocessor.fit_transform(x_train)
    x_test_processed = preprocessor.transform(x_test)

    model = build_model(x_train_processed.shape[1], func='elu')

    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]


    history = model.fit(
        x_train_processed, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )

    y_pred = model.predict(x_test_processed)
    
    y_pred_original = np.expm1(y_pred)
    y_test_original = np.expm1(y_test)
    
    mae = mean_absolute_error(y_test_original, y_pred_original)
    mse = mean_squared_error(y_test_original, y_pred_original)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test_original, y_pred_original)
    
    # Graficos e analises para avaliar o treinamento da IA

    print("\nTraining Results:")
    print(f"Mean Absolute Error: ${mae:,.2f}")
    print(f"Root Mean Squared Error: ${rmse:,.2f}")
    print(f"R² Score: {r2:.4f}")

    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.scatter(y_test_original, y_pred_original, alpha=0.6, label='Predicted vs Actual')
    plt.plot([y_test_original.min(), y_test_original.max()], 
             [y_test_original.min(), y_test_original.max()], color='red', linestyle='--', label='Perfect Prediction')
    plt.title('Actual vs. Predicted Prices')
    plt.xlabel('Actual Prices')
    plt.ylabel('Predicted Prices')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Inicio do treinamento do modelo

# %%
train_model()
# Out:
# C:\Users\akdag\AppData\Local\Temp\ipykernel_14216\3898627256.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Levy'].fillna(levy_med, inplace=True)
# c:\Users\akdag\Desktop\CarPriceAI\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 9.1227 - mae: 8.6131 - val_loss: 6.0022 - val_mae: 6.1319 - learning_rate: 0.0010
# Epoch 2/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3921 - mae: 5.5632 - val_loss: 1.3017 - val_mae: 1.5122 - learning_rate: 0.0010
# Epoch 3/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1932 - mae: 1.3758 - val_loss: 0.6323 - val_mae: 0.7733 - learning_rate: 0.0010
# Epoch 4/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7991 - mae: 0.9774 - val_loss: 0.5563 - val_mae: 0.7396 - learning_rate: 0.0010
# Epoch 5/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7520 - mae: 0.9651 - val_loss: 0.5080 - val_mae: 0.7005 - learning_rate: 0.0010
# Epoch 6/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7250 - mae: 0.9625 - val_loss: 0.5210 - val_mae: 0.7592 - learning_rate: 0.0010
# Epoch 7/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6688 - mae: 0.9160 - val_loss: 0.4803 - val_mae: 0.7135 - learning_rate: 0.0010
# Epoch 8/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6645 - mae: 0.9235 - val_loss: 0.4655 - val_mae: 0.6927 - learning_rate: 0.0010
# Epoch 9/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6447 - mae: 0.9130 - val_loss: 0.4638 - val_mae: 0.7037 - learning_rate: 0.0010
# Epoch 10/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6425 - mae: 0.9153 - val_loss: 0.4476 - val_mae: 0.6747 - learning_rate: 0.0010
# Epoch 11/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6277 - mae: 0.9077 - val_loss: 0.4437 - val_mae: 0.6854 - learning_rate: 0.0010
# Epoch 12/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6364 - mae: 0.9127 - val_loss: 0.4413 - val_mae: 0.6817 - learning_rate: 0.0010
# Epoch 13/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6029 - mae: 0.8838 - val_loss: 0.4373 - val_mae: 0.6802 - learning_rate: 0.0010
# Epoch 14/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6083 - mae: 0.8861 - val_loss: 0.4700 - val_mae: 0.7356 - learning_rate: 0.0010
# Epoch 15/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6032 - mae: 0.8859 - val_loss: 0.4444 - val_mae: 0.7055 - learning_rate: 0.0010
# Epoch 16/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6181 - mae: 0.9046 - val_loss: 0.4272 - val_mae: 0.6701 - learning_rate: 0.0010
# Epoch 17/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6098 - mae: 0.8949 - val_loss: 0.4241 - val_mae: 0.6605 - learning_rate: 0.0010
# Epoch 18/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6108 - mae: 0.8989 - val_loss: 0.4309 - val_mae: 0.6708 - learning_rate: 0.0010
# Epoch 19/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5893 - mae: 0.8758 - val_loss: 0.4145 - val_mae: 0.6444 - learning_rate: 0.0010
# Epoch 20/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5933 - mae: 0.8811 - val_loss: 0.4187 - val_mae: 0.6724 - learning_rate: 0.0010
# Epoch 21/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5992 - mae: 0.8870 - val_loss: 0.4259 - val_mae: 0.6756 - learning_rate: 0.0010
# Epoch 22/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5908 - mae: 0.8806 - val_loss: 0.4442 - val_mae: 0.7026 - learning_rate: 0.0010
# Epoch 23/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5926 - mae: 0.8852 - val_loss: 0.4225 - val_mae: 0.6671 - learning_rate: 0.0010
# Epoch 24/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5752 - mae: 0.8621
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5752 - mae: 0.8621 - val_loss: 0.4195 - val_mae: 0.6520 - learning_rate: 0.0010
# Epoch 25/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5792 - mae: 0.8687 - val_loss: 0.4068 - val_mae: 0.6508 - learning_rate: 2.0000e-04
# Epoch 26/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5635 - mae: 0.8538 - val_loss: 0.4010 - val_mae: 0.6435 - learning_rate: 2.0000e-04
# Epoch 27/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5524 - mae: 0.8389 - val_loss: 0.3990 - val_mae: 0.6430 - learning_rate: 2.0000e-04
# Epoch 28/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5644 - mae: 0.8543 - val_loss: 0.4077 - val_mae: 0.6578 - learning_rate: 2.0000e-04
# Epoch 29/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5500 - mae: 0.8383 - val_loss: 0.3962 - val_mae: 0.6397 - learning_rate: 2.0000e-04
# Epoch 30/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5482 - mae: 0.8413 - val_loss: 0.3994 - val_mae: 0.6464 - learning_rate: 2.0000e-04
# Epoch 31/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5554 - mae: 0.8481 - val_loss: 0.3960 - val_mae: 0.6498 - learning_rate: 2.0000e-04
# Epoch 32/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5313 - mae: 0.8238 - val_loss: 0.3913 - val_mae: 0.6403 - learning_rate: 2.0000e-04
# Epoch 33/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5353 - mae: 0.8266 - val_loss: 0.3930 - val_mae: 0.6400 - learning_rate: 2.0000e-04
# Epoch 34/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5341 - mae: 0.8287 - val_loss: 0.3915 - val_mae: 0.6428 - learning_rate: 2.0000e-04
# Epoch 35/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5344 - mae: 0.8301 - val_loss: 0.4048 - val_mae: 0.6706 - learning_rate: 2.0000e-04
# Epoch 36/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5408 - mae: 0.8374 - val_loss: 0.3939 - val_mae: 0.6512 - learning_rate: 2.0000e-04
# Epoch 37/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5335 - mae: 0.8255 - val_loss: 0.3887 - val_mae: 0.6410 - learning_rate: 2.0000e-04
# Epoch 38/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5509 - mae: 0.8497 - val_loss: 0.3893 - val_mae: 0.6396 - learning_rate: 2.0000e-04
# Epoch 39/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5547 - mae: 0.8539 - val_loss: 0.3939 - val_mae: 0.6514 - learning_rate: 2.0000e-04
# Epoch 40/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5360 - mae: 0.8330 - val_loss: 0.3952 - val_mae: 0.6432 - learning_rate: 2.0000e-04
# Epoch 41/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5391 - mae: 0.8309 - val_loss: 0.3949 - val_mae: 0.6497 - learning_rate: 2.0000e-04
# Epoch 42/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5452 - mae: 0.8456
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5452 - mae: 0.8456 - val_loss: 0.3979 - val_mae: 0.6649 - learning_rate: 2.0000e-04
# Epoch 43/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5324 - mae: 0.8274 - val_loss: 0.3895 - val_mae: 0.6424 - learning_rate: 4.0000e-05
# Epoch 44/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5362 - mae: 0.8327 - val_loss: 0.3890 - val_mae: 0.6429 - learning_rate: 4.0000e-05
# Epoch 45/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5440 - mae: 0.8414 - val_loss: 0.3883 - val_mae: 0.6426 - learning_rate: 4.0000e-05
# Epoch 46/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5483 - mae: 0.8455 - val_loss: 0.3879 - val_mae: 0.6381 - learning_rate: 4.0000e-05
# Epoch 47/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5294 - mae: 0.8232 - val_loss: 0.3883 - val_mae: 0.6417 - learning_rate: 4.0000e-05
# Epoch 48/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5233 - mae: 0.8147 - val_loss: 0.3890 - val_mae: 0.6428 - learning_rate: 4.0000e-05
# Epoch 49/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5425 - mae: 0.8368 - val_loss: 0.3873 - val_mae: 0.6377 - learning_rate: 4.0000e-05
# Epoch 50/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5225 - mae: 0.8171 - val_loss: 0.3889 - val_mae: 0.6424 - learning_rate: 4.0000e-05
# Epoch 51/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5319 - mae: 0.8305 - val_loss: 0.3874 - val_mae: 0.6392 - learning_rate: 4.0000e-05
# Epoch 52/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5335 - mae: 0.8303 - val_loss: 0.3899 - val_mae: 0.6425 - learning_rate: 4.0000e-05
# Epoch 53/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5381 - mae: 0.8346 - val_loss: 0.3874 - val_mae: 0.6415 - learning_rate: 4.0000e-05
# Epoch 54/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5075 - mae: 0.8032 - val_loss: 0.3849 - val_mae: 0.6345 - learning_rate: 4.0000e-05
# Epoch 55/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5396 - mae: 0.8336 - val_loss: 0.3887 - val_mae: 0.6433 - learning_rate: 4.0000e-05
# Epoch 56/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5357 - mae: 0.8352 - val_loss: 0.3872 - val_mae: 0.6387 - learning_rate: 4.0000e-05
# Epoch 57/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5397 - mae: 0.8401 - val_loss: 0.3878 - val_mae: 0.6398 - learning_rate: 4.0000e-05
# Epoch 58/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5307 - mae: 0.8260 - val_loss: 0.3866 - val_mae: 0.6343 - learning_rate: 4.0000e-05
# Epoch 59/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5237 - mae: 0.8228 - val_loss: 0.3843 - val_mae: 0.6341 - learning_rate: 4.0000e-05
# Epoch 60/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5224 - mae: 0.8234 - val_loss: 0.3866 - val_mae: 0.6381 - learning_rate: 4.0000e-05
# Epoch 61/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5405 - mae: 0.8413 - val_loss: 0.3838 - val_mae: 0.6357 - learning_rate: 4.0000e-05
# Epoch 62/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5255 - mae: 0.8213 - val_loss: 0.3846 - val_mae: 0.6377 - learning_rate: 4.0000e-05
# Epoch 63/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5313 - mae: 0.8328 - val_loss: 0.3850 - val_mae: 0.6399 - learning_rate: 4.0000e-05
# Epoch 64/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5387 - mae: 0.8358 - val_loss: 0.3851 - val_mae: 0.6386 - learning_rate: 4.0000e-05
# Epoch 65/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5254 - mae: 0.8214 - val_loss: 0.3847 - val_mae: 0.6397 - learning_rate: 4.0000e-05
# Epoch 66/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5204 - mae: 0.8129
# Epoch 66: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5203 - mae: 0.8129 - val_loss: 0.3858 - val_mae: 0.6420 - learning_rate: 4.0000e-05
# Epoch 67/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5428 - mae: 0.8383 - val_loss: 0.3851 - val_mae: 0.6393 - learning_rate: 8.0000e-06
# Epoch 68/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5335 - mae: 0.8318 - val_loss: 0.3862 - val_mae: 0.6423 - learning_rate: 8.0000e-06
# Epoch 69/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5480 - mae: 0.8459 - val_loss: 0.3852 - val_mae: 0.6406 - learning_rate: 8.0000e-06
# Epoch 70/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5509 - mae: 0.8482 - val_loss: 0.3848 - val_mae: 0.6384 - learning_rate: 8.0000e-06
# Epoch 71/100
# 273/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5209 - mae: 0.8138
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5212 - mae: 0.8143 - val_loss: 0.3842 - val_mae: 0.6377 - learning_rate: 8.0000e-06
# Epoch 72/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5063 - mae: 0.8051 - val_loss: 0.3843 - val_mae: 0.6365 - learning_rate: 1.6000e-06
# Epoch 73/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5337 - mae: 0.8327 - val_loss: 0.3841 - val_mae: 0.6368 - learning_rate: 1.6000e-06
# Epoch 74/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5226 - mae: 0.8167 - val_loss: 0.3846 - val_mae: 0.6382 - learning_rate: 1.6000e-06
# Epoch 75/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5315 - mae: 0.8288 - val_loss: 0.3842 - val_mae: 0.6361 - learning_rate: 1.6000e-06
# Epoch 76/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5290 - mae: 0.8250 - val_loss: 0.3837 - val_mae: 0.6357 - learning_rate: 1.6000e-06
# Epoch 77/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5278 - mae: 0.8253 - val_loss: 0.3835 - val_mae: 0.6355 - learning_rate: 1.6000e-06
# Epoch 78/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5460 - mae: 0.8492 - val_loss: 0.3844 - val_mae: 0.6384 - learning_rate: 1.6000e-06
# Epoch 79/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5051 - mae: 0.8001 - val_loss: 0.3834 - val_mae: 0.6356 - learning_rate: 1.6000e-06
# Epoch 80/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5497 - mae: 0.8511 - val_loss: 0.3837 - val_mae: 0.6350 - learning_rate: 1.6000e-06
# Epoch 81/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5220 - mae: 0.8177 - val_loss: 0.3838 - val_mae: 0.6366 - learning_rate: 1.6000e-06
# Epoch 82/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5249 - mae: 0.8225
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1e-06.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5249 - mae: 0.8224 - val_loss: 0.3837 - val_mae: 0.6364 - learning_rate: 1.6000e-06
# Epoch 83/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5479 - mae: 0.8456 - val_loss: 0.3842 - val_mae: 0.6373 - learning_rate: 1.0000e-06
# Epoch 84/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5120 - mae: 0.8070 - val_loss: 0.3842 - val_mae: 0.6359 - learning_rate: 1.0000e-06
# Epoch 85/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5102 - mae: 0.8093 - val_loss: 0.3843 - val_mae: 0.6378 - learning_rate: 1.0000e-06
# Epoch 86/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5081 - mae: 0.8040 - val_loss: 0.3841 - val_mae: 0.6367 - learning_rate: 1.0000e-06
# Epoch 87/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5018 - mae: 0.7981 - val_loss: 0.3836 - val_mae: 0.6349 - learning_rate: 1.0000e-06
# Epoch 88/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5338 - mae: 0.8320 - val_loss: 0.3840 - val_mae: 0.6366 - learning_rate: 1.0000e-06
# Epoch 89/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5099 - mae: 0.8043 - val_loss: 0.3839 - val_mae: 0.6368 - learning_rate: 1.0000e-06
# Epoch 90/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5147 - mae: 0.8116 - val_loss: 0.3847 - val_mae: 0.6362 - learning_rate: 1.0000e-06
# Epoch 91/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5328 - mae: 0.8294 - val_loss: 0.3836 - val_mae: 0.6351 - learning_rate: 1.0000e-06
# Epoch 92/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5300 - mae: 0.8235 - val_loss: 0.3831 - val_mae: 0.6355 - learning_rate: 1.0000e-06
# Epoch 93/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5262 - mae: 0.8220 - val_loss: 0.3841 - val_mae: 0.6386 - learning_rate: 1.0000e-06
# Epoch 94/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5405 - mae: 0.8369 - val_loss: 0.3836 - val_mae: 0.6364 - learning_rate: 1.0000e-06
# Epoch 95/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5248 - mae: 0.8194 - val_loss: 0.3835 - val_mae: 0.6345 - learning_rate: 1.0000e-06
# Epoch 96/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5278 - mae: 0.8272 - val_loss: 0.3835 - val_mae: 0.6352 - learning_rate: 1.0000e-06
# Epoch 97/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5323 - mae: 0.8297 - val_loss: 0.3841 - val_mae: 0.6369 - learning_rate: 1.0000e-06
# Epoch 98/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5407 - mae: 0.8427 - val_loss: 0.3838 - val_mae: 0.6369 - learning_rate: 1.0000e-06
# Epoch 99/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5195 - mae: 0.8152 - val_loss: 0.3838 - val_mae: 0.6371 - learning_rate: 1.0000e-06
# Epoch 100/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5480 - mae: 0.8498 - val_loss: 0.3838 - val_mae: 0.6374 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 92.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Training Results:
# Mean Absolute Error: $4,978.48
# Root Mean Squared Error: $7,664.15
# R² Score: 0.5352

# %% [markdown]
# # Resultados - ELU
# ## Test 1
#
# Com a funçao ELU, o treinamento foi um pouco mais lento, e a precisão foi inferior.
#
# - Funcao: Relu
# - Epocas: 100
# - Divisão dos dados: 32
# - Taxa de aprendizdo inicial (varia com as epocas): 0.001
# ---
#
# Erro médio absolute nas predições(`MAE`): $4,978.48
#
# Erro quadratico médio (`RMSE`): $7,664.15
#
# Coenficiente de determinação (`R² Score`): 0.5352
