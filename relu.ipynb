# %% [markdown]
# # Processamento do Dataset
#
# ## Função para ler os dados do Dataset e processar
#
# - Substitui dados vazios da coluna Levy(Taxas) pela media
# - Aplica um processamento de texto para remover o texto km da coluna Mileahe(Milhas)
# - Extrai apenas o valor do volume do motor
# - Remove colunas desnecessarias ou dificeis de processar como ID e Model
# - Remove os valores muito fora da media das colunas numericas
#
# ### Aplica uma normaliçao numerica
#
# Utilizado a funçao log1p (log(1 + x)) para preservars valores 0 e normalizar os dados,
# dessa forma, muito comum quando os dados são muito assimetricos, facilita o processamento com a IA.
#
# Apos isso, para reverter os dados ao estado original, usei a funçao expm1 ( exp(x) - 1 )

# %%
import pandas as pd
import numpy as np

def process_data():
    data = pd.read_csv("./car_price_prediction.csv", sep=",")

    data['Levy'] = pd.to_numeric(data['Levy'], errors='coerce')
    levy_med = data['Levy'].median()
    data['Levy'].fillna(levy_med, inplace=True)

    data['Mileage'] = data['Mileage'].str.replace(' km', '', regex=False).astype(float)

    data['Engine volume'] = data['Engine volume'].str.extract(r'(\d+\.?\d*)').astype(float)

    data = data.drop(columns=['ID', 'Model'])

    num_columns = ['Price', 'Levy', 'Mileage', 'Engine volume']
    for col in num_columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        data = data[~((data[col] < lower_bound) | (data[col] > upper_bound))]


    data['Price'] = np.log1p(data['Price']) 
    data['Mileage'] = np.log1p(data['Mileage'])
    data['Levy'] = np.log1p(data['Levy'])

    y = data['Price']
    x = data.drop(columns=["Price"])

    return x, y

# %% [markdown]
# # Funçao de build do modelo
#
# ## Constroi as camadas de neuronios e aplica as funções matematicas
#
# 1. Camada de Input(entrada) - 64 neuronios
# 2. Camada escondida - 32 neuronios
# 3. Camada escondida - 16 neuronios
# 4. Cama escondida - 8 neuronios
# 5. Camada de saida
#
# ### Funçoes adicionais
#
# - Nas camadas é aplicado o L2 regularization. Altera a penalidade da funçao de perda, para que a Ia
# não dependa muito de pesos muito altos.
#
# - Dropout: Aplicado entre as Layers para ignorar uma porcentagem dos neuronios, tambem ajuda a IA
# a não depender muito de neuronios especificos.
#
# - BatchNormalization: normaliza os outputs das camadas para garantir que eles tenham uma media de 0 e um desvio
# padrão de 1, o que ajuda a encontrar padrões mais rapido

# %%
from keras.api.models import Sequential
from keras.api.layers import Dense, BatchNormalization, Dropout
from keras.api.optimizers import Adam
from keras.api.regularizers import l2


def build_model(dimension, func='relu', eta=0.001):
    model = Sequential([
        Dense(64, activation=func, input_dim=dimension, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.2),

        Dense(16, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.1),

        Dense(8, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.03),

        Dense(1)
    ])

    optimizer = Adam(learning_rate=eta)
    model.compile(optimizer=optimizer, loss='huber', metrics=['mae'])

    return model

# %% [markdown]
# # Função de Treinamento do Modelo
#
# ## Pré-processamento dos Dados
# - A função começa dividindo o conjunto de dados em conjuntos de treino e teste, com 80% dos dados para treinamento e 20% para teste.
#
# #### Transformadores e Escaladores
# - Para as variáveis numéricas, a transformação `StandardScaler` é aplicada para normalizar os dados, removendo a média e escalando para que a variância seja 1.
# - Para as variaveis categoricas, `OneHotEncoder` cria colunas binárias para representar cada categoria
#
# ---
#
# ## Construção do Modelo
# **Callbacks do Keras utilizdos para melhorar o treinamento**:
#    - **EarlyStopping**: Para evitar o overfitting, é aplicado um monitoramento do `val_loss`, que interrompe o treinamento caso a perda de validação não melhore após 15 épocas.
#    - **ReduceLROnPlateau**: Reduz a taxa de aprendizado se a perda de validação não melhorar após 5 épocas, ajustando dinamicamente a taxa de aprendizado.
#
# ---
#
# ## Avaliação do Modelo
#
# **Métricas de Performance**:
#    - **Erro Absoluto Médio (MAE)**: Mede a diferença média entre o preço real e o preço previsto, dando uma ideia do erro médio do modelo.
#    - **Erro Quadrático Médio (MSE)**: Penaliza erros maiores, pois eleva os erros ao quadrado.
#    - **Raiz do Erro Quadrático Médio (RMSE)**: A raiz quadrada do MSE, traz o erro de volta a escala dos preçoes.
#    - **Coeficiente de Determinação (R²)**: Mede a proporção da variabilidade do preço. Valores mais próximos de 1 indicando bons resultados.
#
# ---
#
# ## Visualização dos Resultados
#
# 1. **Curvas de Perda (Loss)**:
#    - A evolução da perda durante o treinamento e validação é plotada para acompanhar o progresso do modelo e verificar se está ocorrendo overfitting.
#
# 2. **Gráfico de Preço Real vs. Preço Predito**:
#    - Grafico de disperção com uma linha vermelha indicando o valor correto, e o que foi chutado pela IA

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.api.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer

def train_model():
    x, y = process_data()

    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.2, random_state=42
    )

    numeric_features = [
        'Levy', 'Prod. year', 'Engine volume', 
        'Mileage', 'Cylinders', 'Airbags', 'Doors'
    ]
    
    categorical_features = [
        'Manufacturer', 'Category', 'Leather interior',
        'Fuel type', 'Gear box type', 'Drive wheels',
        'Wheel', 'Color'
    ]

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), numeric_features),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])
    
    x_train_processed = preprocessor.fit_transform(x_train)
    x_test_processed = preprocessor.transform(x_test)

    model = build_model(x_train_processed.shape[1])

    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]


    history = model.fit(
        x_train_processed, y_train,
        validation_split=0.2,
        epochs=100,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )

    y_pred = model.predict(x_test_processed)
    
    y_pred_original = np.expm1(y_pred)
    y_test_original = np.expm1(y_test)
    
    mae = mean_absolute_error(y_test_original, y_pred_original)
    mse = mean_squared_error(y_test_original, y_pred_original)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test_original, y_pred_original)
    
    # Graficos e analises para avaliar o treinamento da IA

    print("\nTraining Results:")
    print(f"Mean Absolute Error: ${mae:,.2f}")
    print(f"Root Mean Squared Error: ${rmse:,.2f}")
    print(f"R² Score: {r2:.4f}")

    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.scatter(y_test_original, y_pred_original, alpha=0.6, label='Predicted vs Actual')
    plt.plot([y_test_original.min(), y_test_original.max()], 
             [y_test_original.min(), y_test_original.max()], color='red', linestyle='--', label='Perfect Prediction')
    plt.title('Actual vs. Predicted Prices')
    plt.xlabel('Actual Prices')
    plt.ylabel('Predicted Prices')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Inicio do treinamento do modelo

# %%
train_model()
# Out:
# C:\Users\akdag\AppData\Local\Temp\ipykernel_11796\3898627256.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Levy'].fillna(levy_med, inplace=True)
# c:\Users\akdag\Desktop\CarPriceAI\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 9.2111 - mae: 8.6814 - val_loss: 7.2970 - val_mae: 7.3857 - learning_rate: 0.0010
# Epoch 2/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.6999 - mae: 5.8245 - val_loss: 1.8975 - val_mae: 2.0640 - learning_rate: 0.0010
# Epoch 3/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4617 - mae: 1.5992 - val_loss: 0.7329 - val_mae: 0.8147 - learning_rate: 0.0010
# Epoch 4/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9195 - mae: 1.0376 - val_loss: 0.6371 - val_mae: 0.7515 - learning_rate: 0.0010
# Epoch 5/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8151 - mae: 0.9651 - val_loss: 0.5856 - val_mae: 0.7349 - learning_rate: 0.0010
# Epoch 6/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7416 - mae: 0.9169 - val_loss: 0.5513 - val_mae: 0.7262 - learning_rate: 0.0010
# Epoch 7/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7102 - mae: 0.9071 - val_loss: 0.5153 - val_mae: 0.6867 - learning_rate: 0.0010
# Epoch 8/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6803 - mae: 0.8953 - val_loss: 0.4924 - val_mae: 0.6732 - learning_rate: 0.0010
# Epoch 9/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6402 - mae: 0.8717 - val_loss: 0.4741 - val_mae: 0.6734 - learning_rate: 0.0010
# Epoch 10/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6396 - mae: 0.8823 - val_loss: 0.4713 - val_mae: 0.6792 - learning_rate: 0.0010
# Epoch 11/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6269 - mae: 0.8752 - val_loss: 0.4660 - val_mae: 0.6841 - learning_rate: 0.0010
# Epoch 12/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5836 - mae: 0.8351 - val_loss: 0.4475 - val_mae: 0.6437 - learning_rate: 0.0010
# Epoch 13/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5912 - mae: 0.8418 - val_loss: 0.4370 - val_mae: 0.6473 - learning_rate: 0.0010
# Epoch 14/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5691 - mae: 0.8256 - val_loss: 0.4330 - val_mae: 0.6583 - learning_rate: 0.0010
# Epoch 15/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5689 - mae: 0.8310 - val_loss: 0.4259 - val_mae: 0.6692 - learning_rate: 0.0010
# Epoch 16/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5757 - mae: 0.8446 - val_loss: 0.4225 - val_mae: 0.6431 - learning_rate: 0.0010
# Epoch 17/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5587 - mae: 0.8244 - val_loss: 0.4158 - val_mae: 0.6462 - learning_rate: 0.0010
# Epoch 18/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5614 - mae: 0.8353 - val_loss: 0.4157 - val_mae: 0.6580 - learning_rate: 0.0010
# Epoch 19/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5657 - mae: 0.8418 - val_loss: 0.4144 - val_mae: 0.6535 - learning_rate: 0.0010
# Epoch 20/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5591 - mae: 0.8335 - val_loss: 0.4207 - val_mae: 0.6578 - learning_rate: 0.0010
# Epoch 21/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5434 - mae: 0.8208 - val_loss: 0.4027 - val_mae: 0.6277 - learning_rate: 0.0010
# Epoch 22/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5451 - mae: 0.8274 - val_loss: 0.4063 - val_mae: 0.6417 - learning_rate: 0.0010
# Epoch 23/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5593 - mae: 0.8419 - val_loss: 0.4039 - val_mae: 0.6276 - learning_rate: 0.0010
# Epoch 24/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5221 - mae: 0.8015 - val_loss: 0.4197 - val_mae: 0.6661 - learning_rate: 0.0010
# Epoch 25/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5478 - mae: 0.8297 - val_loss: 0.4356 - val_mae: 0.6961 - learning_rate: 0.0010
# Epoch 26/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5455 - mae: 0.8226
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5453 - mae: 0.8226 - val_loss: 0.4414 - val_mae: 0.6933 - learning_rate: 0.0010
# Epoch 27/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5061 - mae: 0.7833 - val_loss: 0.3825 - val_mae: 0.6118 - learning_rate: 2.0000e-04
# Epoch 28/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5058 - mae: 0.7871 - val_loss: 0.3764 - val_mae: 0.6063 - learning_rate: 2.0000e-04
# Epoch 29/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5096 - mae: 0.7936 - val_loss: 0.3735 - val_mae: 0.6040 - learning_rate: 2.0000e-04
# Epoch 30/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5014 - mae: 0.7809 - val_loss: 0.3780 - val_mae: 0.6046 - learning_rate: 2.0000e-04
# Epoch 31/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4870 - mae: 0.7684 - val_loss: 0.3646 - val_mae: 0.5939 - learning_rate: 2.0000e-04
# Epoch 32/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4909 - mae: 0.7778 - val_loss: 0.3623 - val_mae: 0.5917 - learning_rate: 2.0000e-04
# Epoch 33/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4811 - mae: 0.7669 - val_loss: 0.3598 - val_mae: 0.5865 - learning_rate: 2.0000e-04
# Epoch 34/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4735 - mae: 0.7593 - val_loss: 0.3574 - val_mae: 0.5838 - learning_rate: 2.0000e-04
# Epoch 35/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4857 - mae: 0.7738 - val_loss: 0.3645 - val_mae: 0.6112 - learning_rate: 2.0000e-04
# Epoch 36/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4820 - mae: 0.7692 - val_loss: 0.3546 - val_mae: 0.5775 - learning_rate: 2.0000e-04
# Epoch 37/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4768 - mae: 0.7663 - val_loss: 0.3575 - val_mae: 0.5994 - learning_rate: 2.0000e-04
# Epoch 38/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4735 - mae: 0.7621 - val_loss: 0.3564 - val_mae: 0.5927 - learning_rate: 2.0000e-04
# Epoch 39/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4599 - mae: 0.7483 - val_loss: 0.3682 - val_mae: 0.6021 - learning_rate: 2.0000e-04
# Epoch 40/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4770 - mae: 0.7644 - val_loss: 0.3575 - val_mae: 0.5935 - learning_rate: 2.0000e-04
# Epoch 41/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4683 - mae: 0.7584 - val_loss: 0.3522 - val_mae: 0.5849 - learning_rate: 2.0000e-04
# Epoch 42/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4568 - mae: 0.7437 - val_loss: 0.3597 - val_mae: 0.5952 - learning_rate: 2.0000e-04
# Epoch 43/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4844 - mae: 0.7759 - val_loss: 0.3472 - val_mae: 0.5818 - learning_rate: 2.0000e-04
# Epoch 44/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4743 - mae: 0.7610 - val_loss: 0.3499 - val_mae: 0.5850 - learning_rate: 2.0000e-04
# Epoch 45/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4651 - mae: 0.7555 - val_loss: 0.3460 - val_mae: 0.5780 - learning_rate: 2.0000e-04
# Epoch 46/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4677 - mae: 0.7566 - val_loss: 0.3503 - val_mae: 0.5928 - learning_rate: 2.0000e-04
# Epoch 47/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4543 - mae: 0.7445 - val_loss: 0.3540 - val_mae: 0.5947 - learning_rate: 2.0000e-04
# Epoch 48/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4559 - mae: 0.7473 - val_loss: 0.3463 - val_mae: 0.5807 - learning_rate: 2.0000e-04
# Epoch 49/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4635 - mae: 0.7545 - val_loss: 0.3419 - val_mae: 0.5701 - learning_rate: 2.0000e-04
# Epoch 50/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4741 - mae: 0.7699 - val_loss: 0.3428 - val_mae: 0.5734 - learning_rate: 2.0000e-04
# Epoch 51/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4632 - mae: 0.7535 - val_loss: 0.3510 - val_mae: 0.5984 - learning_rate: 2.0000e-04
# Epoch 52/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4627 - mae: 0.7552 - val_loss: 0.3384 - val_mae: 0.5738 - learning_rate: 2.0000e-04
# Epoch 53/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4614 - mae: 0.7546 - val_loss: 0.3377 - val_mae: 0.5635 - learning_rate: 2.0000e-04
# Epoch 54/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4555 - mae: 0.7476 - val_loss: 0.3437 - val_mae: 0.5791 - learning_rate: 2.0000e-04
# Epoch 55/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4486 - mae: 0.7385 - val_loss: 0.3380 - val_mae: 0.5681 - learning_rate: 2.0000e-04
# Epoch 56/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4339 - mae: 0.7192 - val_loss: 0.3404 - val_mae: 0.5803 - learning_rate: 2.0000e-04
# Epoch 57/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4465 - mae: 0.7332 - val_loss: 0.3376 - val_mae: 0.5772 - learning_rate: 2.0000e-04
# Epoch 58/100
# 273/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4545 - mae: 0.7448
# Epoch 58: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4543 - mae: 0.7445 - val_loss: 0.3396 - val_mae: 0.5764 - learning_rate: 2.0000e-04
# Epoch 59/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4521 - mae: 0.7443 - val_loss: 0.3365 - val_mae: 0.5670 - learning_rate: 4.0000e-05
# Epoch 60/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4346 - mae: 0.7234 - val_loss: 0.3343 - val_mae: 0.5604 - learning_rate: 4.0000e-05
# Epoch 61/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4578 - mae: 0.7510 - val_loss: 0.3368 - val_mae: 0.5635 - learning_rate: 4.0000e-05
# Epoch 62/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4435 - mae: 0.7296 - val_loss: 0.3329 - val_mae: 0.5630 - learning_rate: 4.0000e-05
# Epoch 63/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4239 - mae: 0.7109 - val_loss: 0.3320 - val_mae: 0.5564 - learning_rate: 4.0000e-05
# Epoch 64/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4200 - mae: 0.7084 - val_loss: 0.3327 - val_mae: 0.5605 - learning_rate: 4.0000e-05
# Epoch 65/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.4364 - mae: 0.7274 - val_loss: 0.3308 - val_mae: 0.5573 - learning_rate: 4.0000e-05
# Epoch 66/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4335 - mae: 0.7196 - val_loss: 0.3301 - val_mae: 0.5549 - learning_rate: 4.0000e-05
# Epoch 67/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4240 - mae: 0.7117 - val_loss: 0.3292 - val_mae: 0.5546 - learning_rate: 4.0000e-05
# Epoch 68/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4572 - mae: 0.7490 - val_loss: 0.3320 - val_mae: 0.5585 - learning_rate: 4.0000e-05
# Epoch 69/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4436 - mae: 0.7384 - val_loss: 0.3279 - val_mae: 0.5561 - learning_rate: 4.0000e-05
# Epoch 70/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4193 - mae: 0.7080 - val_loss: 0.3296 - val_mae: 0.5547 - learning_rate: 4.0000e-05
# Epoch 71/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4385 - mae: 0.7314 - val_loss: 0.3313 - val_mae: 0.5621 - learning_rate: 4.0000e-05
# Epoch 72/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4280 - mae: 0.7146 - val_loss: 0.3305 - val_mae: 0.5647 - learning_rate: 4.0000e-05
# Epoch 73/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4375 - mae: 0.7255 - val_loss: 0.3312 - val_mae: 0.5589 - learning_rate: 4.0000e-05
# Epoch 74/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4335 - mae: 0.7222
# Epoch 74: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4335 - mae: 0.7222 - val_loss: 0.3293 - val_mae: 0.5594 - learning_rate: 4.0000e-05
# Epoch 75/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4296 - mae: 0.7189 - val_loss: 0.3278 - val_mae: 0.5547 - learning_rate: 8.0000e-06
# Epoch 76/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4316 - mae: 0.7187 - val_loss: 0.3290 - val_mae: 0.5553 - learning_rate: 8.0000e-06
# Epoch 77/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4168 - mae: 0.7048 - val_loss: 0.3273 - val_mae: 0.5516 - learning_rate: 8.0000e-06
# Epoch 78/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4279 - mae: 0.7175 - val_loss: 0.3304 - val_mae: 0.5583 - learning_rate: 8.0000e-06
# Epoch 79/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4477 - mae: 0.7390 - val_loss: 0.3291 - val_mae: 0.5579 - learning_rate: 8.0000e-06
# Epoch 80/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4262 - mae: 0.7166 - val_loss: 0.3306 - val_mae: 0.5589 - learning_rate: 8.0000e-06
# Epoch 81/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4341 - mae: 0.7237 - val_loss: 0.3284 - val_mae: 0.5544 - learning_rate: 8.0000e-06
# Epoch 82/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4268 - mae: 0.7165
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4272 - mae: 0.7169 - val_loss: 0.3294 - val_mae: 0.5550 - learning_rate: 8.0000e-06
# Epoch 83/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4451 - mae: 0.7416 - val_loss: 0.3297 - val_mae: 0.5569 - learning_rate: 1.6000e-06
# Epoch 84/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4246 - mae: 0.7119 - val_loss: 0.3289 - val_mae: 0.5542 - learning_rate: 1.6000e-06
# Epoch 85/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4265 - mae: 0.7129 - val_loss: 0.3293 - val_mae: 0.5550 - learning_rate: 1.6000e-06
# Epoch 86/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4093 - mae: 0.6945 - val_loss: 0.3273 - val_mae: 0.5542 - learning_rate: 1.6000e-06
# Epoch 87/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4311 - mae: 0.7211
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1e-06.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4310 - mae: 0.7210 - val_loss: 0.3277 - val_mae: 0.5541 - learning_rate: 1.6000e-06
# Epoch 88/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4248 - mae: 0.7112 - val_loss: 0.3283 - val_mae: 0.5544 - learning_rate: 1.0000e-06
# Epoch 89/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4280 - mae: 0.7159 - val_loss: 0.3282 - val_mae: 0.5552 - learning_rate: 1.0000e-06
# Epoch 90/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4316 - mae: 0.7252 - val_loss: 0.3278 - val_mae: 0.5543 - learning_rate: 1.0000e-06
# Epoch 91/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4293 - mae: 0.7186 - val_loss: 0.3274 - val_mae: 0.5528 - learning_rate: 1.0000e-06
# Epoch 92/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4390 - mae: 0.7336 - val_loss: 0.3296 - val_mae: 0.5568 - learning_rate: 1.0000e-06
# Epoch 92: early stopping
# Restoring model weights from the end of the best epoch: 77.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# Training Results:
# Mean Absolute Error: $4,220.47
# Root Mean Squared Error: $6,644.11
# R² Score: 0.6507

# %% [markdown]
# # Resultados - RELU
# ## Test 1
#
# - Funcao: Relu
# - Epocas: 100
# - Divisão dos dados: 32
# - Taxa de aprendizdo inicial (varia com as epocas): 0.001
# ---
#
# Erro médio absolute nas predições(`MAE`): $4,220.47
#
# Erro quadratico médio (`RMSE`): $6,644.11
#
# Coenficiente de determinação (`R² Score`): 0.6507
