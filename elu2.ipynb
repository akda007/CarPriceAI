# %% [markdown]
# # Processamento do Dataset
#
# ## Função para ler os dados do Dataset e processar
#
# - Substitui dados vazios da coluna Levy(Taxas) pela media
# - Aplica um processamento de texto para remover o texto km da coluna Mileahe(Milhas)
# - Extrai apenas o valor do volume do motor
# - Remove colunas desnecessarias ou dificeis de processar como ID e Model
# - Remove os valores muito fora da media das colunas numericas
#
# ### Aplica uma normaliçao numerica
#
# Utilizado a funçao log1p (log(1 + x)) para preservars valores 0 e normalizar os dados,
# dessa forma, muito comum quando os dados são muito assimetricos, facilita o processamento com a IA.
#
# Apos isso, para reverter os dados ao estado original, usei a funçao expm1 ( exp(x) - 1 )

# %%
import pandas as pd
import numpy as np

def process_data():
    data = pd.read_csv("./car_price_prediction.csv", sep=",")

    data['Levy'] = pd.to_numeric(data['Levy'], errors='coerce')
    levy_med = data['Levy'].median()
    data['Levy'].fillna(levy_med, inplace=True)

    data['Mileage'] = data['Mileage'].str.replace(' km', '', regex=False).astype(float)

    data['Engine volume'] = data['Engine volume'].str.extract(r'(\d+\.?\d*)').astype(float)

    data = data.drop(columns=['ID', 'Model'])

    num_columns = ['Price', 'Levy', 'Mileage', 'Engine volume']
    for col in num_columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        data = data[~((data[col] < lower_bound) | (data[col] > upper_bound))]


    data['Price'] = np.log1p(data['Price']) 
    data['Mileage'] = np.log1p(data['Mileage'])
    data['Levy'] = np.log1p(data['Levy'])

    y = data['Price']
    x = data.drop(columns=["Price"])

    return x, y

# %% [markdown]
# # Funçao de build do modelo
#
# ## Constroi as camadas de neuronios e aplica as funções matematicas
#
# 1. Camada de Input(entrada) - 64 neuronios
# 2. Camada escondida - 32 neuronios
# 3. Camada escondida - 16 neuronios
# 4. Cama escondida - 8 neuronios
# 5. Camada de saida
#
# ### Funçoes adicionais
#
# - Nas camadas é aplicado o L2 regularization. Altera a penalidade da funçao de perda, para que a Ia
# não dependa muito de pesos muito altos.
#
# - Dropout: Aplicado entre as Layers para ignorar uma porcentagem dos neuronios, tambem ajuda a IA
# a não depender muito de neuronios especificos.
#
# - BatchNormalization: normaliza os outputs das camadas para garantir que eles tenham uma media de 0 e um desvio
# padrão de 1, o que ajuda a encontrar padrões mais rapido

# %%
from keras.api.models import Sequential
from keras.api.layers import Dense, BatchNormalization, Dropout
from keras.api.optimizers import Adam
from keras.api.regularizers import l2


def build_model(dimension, func='relu', eta=0.001):
    model = Sequential([
        Dense(64, activation=func, input_dim=dimension, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.2),

        Dense(16, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.1),

        Dense(8, activation=func, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.03),

        Dense(1)
    ])

    optimizer = Adam(learning_rate=eta)
    model.compile(optimizer=optimizer, loss='huber', metrics=['mae'])

    return model

# %% [markdown]
# # Função de Treinamento do Modelo
#
# ## Pré-processamento dos Dados
# - A função começa dividindo o conjunto de dados em conjuntos de treino e teste, com 80% dos dados para treinamento e 20% para teste.
#
# #### Transformadores e Escaladores
# - Para as variáveis numéricas, a transformação `StandardScaler` é aplicada para normalizar os dados, removendo a média e escalando para que a variância seja 1.
# - Para as variaveis categoricas, `OneHotEncoder` cria colunas binárias para representar cada categoria
#
# ---
#
# ## Construção do Modelo
# **Callbacks do Keras utilizdos para melhorar o treinamento**:
#    - **EarlyStopping**: Para evitar o overfitting, é aplicado um monitoramento do `val_loss`, que interrompe o treinamento caso a perda de validação não melhore após 15 épocas.
#    - **ReduceLROnPlateau**: Reduz a taxa de aprendizado se a perda de validação não melhorar após 5 épocas, ajustando dinamicamente a taxa de aprendizado.
#
# ---
#
# ## Avaliação do Modelo
#
# **Métricas de Performance**:
#    - **Erro Absoluto Médio (MAE)**: Mede a diferença média entre o preço real e o preço previsto, dando uma ideia do erro médio do modelo.
#    - **Erro Quadrático Médio (MSE)**: Penaliza erros maiores, pois eleva os erros ao quadrado.
#    - **Raiz do Erro Quadrático Médio (RMSE)**: A raiz quadrada do MSE, traz o erro de volta a escala dos preçoes.
#    - **Coeficiente de Determinação (R²)**: Mede a proporção da variabilidade do preço. Valores mais próximos de 1 indicando bons resultados.
#
# ---
#
# ## Visualização dos Resultados
#
# 1. **Curvas de Perda (Loss)**:
#    - A evolução da perda durante o treinamento e validação é plotada para acompanhar o progresso do modelo e verificar se está ocorrendo overfitting.
#
# 2. **Gráfico de Preço Real vs. Preço Predito**:
#    - Grafico de disperção com uma linha vermelha indicando o valor correto, e o que foi chutado pela IA

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.api.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer

def train_model():
    x, y = process_data()

    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.2, random_state=42
    )

    numeric_features = [
        'Levy', 'Prod. year', 'Engine volume', 
        'Mileage', 'Cylinders', 'Airbags', 'Doors'
    ]
    
    categorical_features = [
        'Manufacturer', 'Category', 'Leather interior',
        'Fuel type', 'Gear box type', 'Drive wheels',
        'Wheel', 'Color'
    ]

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), numeric_features),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])
    
    x_train_processed = preprocessor.fit_transform(x_train)
    x_test_processed = preprocessor.transform(x_test)

    model = build_model(x_train_processed.shape[1], func='elu')

    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]


    history = model.fit(
        x_train_processed, y_train,
        validation_split=0.2,
        epochs=120,
        batch_size=50,
        callbacks=callbacks,
        verbose=1
    )

    y_pred = model.predict(x_test_processed)
    
    y_pred_original = np.expm1(y_pred)
    y_test_original = np.expm1(y_test)
    
    mae = mean_absolute_error(y_test_original, y_pred_original)
    mse = mean_squared_error(y_test_original, y_pred_original)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test_original, y_pred_original)
    
    # Graficos e analises para avaliar o treinamento da IA

    print("\nTraining Results:")
    print(f"Mean Absolute Error: ${mae:,.2f}")
    print(f"Root Mean Squared Error: ${rmse:,.2f}")
    print(f"R² Score: {r2:.4f}")

    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.scatter(y_test_original, y_pred_original, alpha=0.6, label='Predicted vs Actual')
    plt.plot([y_test_original.min(), y_test_original.max()], 
             [y_test_original.min(), y_test_original.max()], color='red', linestyle='--', label='Perfect Prediction')
    plt.title('Actual vs. Predicted Prices')
    plt.xlabel('Actual Prices')
    plt.ylabel('Predicted Prices')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Inicio do treinamento do modelo

# %%
train_model()
# Out:
# C:\Users\akdag\AppData\Local\Temp\ipykernel_9896\3898627256.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Levy'].fillna(levy_med, inplace=True)
# c:\Users\akdag\Desktop\CarPriceAI\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 9.4278 - mae: 8.7890 - val_loss: 7.9511 - val_mae: 7.9504 - learning_rate: 0.0010
# Epoch 2/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.1452 - mae: 7.2154 - val_loss: 5.1109 - val_mae: 5.3258 - learning_rate: 0.0010
# Epoch 3/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2533 - mae: 4.4884 - val_loss: 1.6359 - val_mae: 1.9009 - learning_rate: 0.0010
# Epoch 4/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3230 - mae: 1.5578 - val_loss: 0.6310 - val_mae: 0.7752 - learning_rate: 0.0010
# Epoch 5/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8044 - mae: 1.0023 - val_loss: 0.5736 - val_mae: 0.7333 - learning_rate: 0.0010
# Epoch 6/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7431 - mae: 0.9625 - val_loss: 0.5211 - val_mae: 0.7021 - learning_rate: 0.0010
# Epoch 7/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7084 - mae: 0.9406 - val_loss: 0.4968 - val_mae: 0.7026 - learning_rate: 0.0010
# Epoch 8/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6559 - mae: 0.8997 - val_loss: 0.4787 - val_mae: 0.6899 - learning_rate: 0.0010
# Epoch 9/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6692 - mae: 0.9268 - val_loss: 0.4694 - val_mae: 0.6793 - learning_rate: 0.0010
# Epoch 10/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6726 - mae: 0.9442 - val_loss: 0.4608 - val_mae: 0.6800 - learning_rate: 0.0010
# Epoch 11/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6503 - mae: 0.9238 - val_loss: 0.4441 - val_mae: 0.6658 - learning_rate: 0.0010
# Epoch 12/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6232 - mae: 0.8938 - val_loss: 0.4412 - val_mae: 0.6760 - learning_rate: 0.0010
# Epoch 13/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6172 - mae: 0.8931 - val_loss: 0.4366 - val_mae: 0.6639 - learning_rate: 0.0010
# Epoch 14/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6036 - mae: 0.8785 - val_loss: 0.4271 - val_mae: 0.6590 - learning_rate: 0.0010
# Epoch 15/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6087 - mae: 0.8907 - val_loss: 0.4296 - val_mae: 0.6652 - learning_rate: 0.0010
# Epoch 16/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6117 - mae: 0.8913 - val_loss: 0.4440 - val_mae: 0.6839 - learning_rate: 0.0010
# Epoch 17/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6013 - mae: 0.8780 - val_loss: 0.4259 - val_mae: 0.6767 - learning_rate: 0.0010
# Epoch 18/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5934 - mae: 0.8727 - val_loss: 0.4244 - val_mae: 0.6776 - learning_rate: 0.0010
# Epoch 19/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6032 - mae: 0.8887 - val_loss: 0.4126 - val_mae: 0.6415 - learning_rate: 0.0010
# Epoch 20/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6095 - mae: 0.8959 - val_loss: 0.4269 - val_mae: 0.6756 - learning_rate: 0.0010
# Epoch 21/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5803 - mae: 0.8646 - val_loss: 0.4262 - val_mae: 0.6825 - learning_rate: 0.0010
# Epoch 22/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5909 - mae: 0.8778 - val_loss: 0.4122 - val_mae: 0.6545 - learning_rate: 0.0010
# Epoch 23/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5668 - mae: 0.8474 - val_loss: 0.4355 - val_mae: 0.6934 - learning_rate: 0.0010
# Epoch 24/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5757 - mae: 0.8623 - val_loss: 0.4147 - val_mae: 0.6599 - learning_rate: 0.0010
# Epoch 25/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5948 - mae: 0.8786 - val_loss: 0.4092 - val_mae: 0.6499 - learning_rate: 0.0010
# Epoch 26/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5770 - mae: 0.8623 - val_loss: 0.4210 - val_mae: 0.6717 - learning_rate: 0.0010
# Epoch 27/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5692 - mae: 0.8569 - val_loss: 0.4375 - val_mae: 0.7216 - learning_rate: 0.0010
# Epoch 28/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5826 - mae: 0.8685 - val_loss: 0.4230 - val_mae: 0.6752 - learning_rate: 0.0010
# Epoch 29/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5828 - mae: 0.8724 - val_loss: 0.4115 - val_mae: 0.6531 - learning_rate: 0.0010
# Epoch 30/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5642 - mae: 0.8533 - val_loss: 0.4083 - val_mae: 0.6585 - learning_rate: 0.0010
# Epoch 31/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5423 - mae: 0.8278 - val_loss: 0.4060 - val_mae: 0.6467 - learning_rate: 0.0010
# Epoch 32/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5538 - mae: 0.8410 - val_loss: 0.4392 - val_mae: 0.7000 - learning_rate: 0.0010
# Epoch 33/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5676 - mae: 0.8570 - val_loss: 0.4115 - val_mae: 0.6556 - learning_rate: 0.0010
# Epoch 34/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5655 - mae: 0.8536 - val_loss: 0.4126 - val_mae: 0.6599 - learning_rate: 0.0010
# Epoch 35/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5523 - mae: 0.8419 - val_loss: 0.4055 - val_mae: 0.6367 - learning_rate: 0.0010
# Epoch 36/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5647 - mae: 0.8525 - val_loss: 0.4167 - val_mae: 0.6496 - learning_rate: 0.0010
# Epoch 37/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5697 - mae: 0.8582 - val_loss: 0.4100 - val_mae: 0.6695 - learning_rate: 0.0010
# Epoch 38/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5477 - mae: 0.8380 - val_loss: 0.4040 - val_mae: 0.6375 - learning_rate: 0.0010
# Epoch 39/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5497 - mae: 0.8352 - val_loss: 0.4095 - val_mae: 0.6422 - learning_rate: 0.0010
# Epoch 40/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5465 - mae: 0.8339 - val_loss: 0.4104 - val_mae: 0.6515 - learning_rate: 0.0010
# Epoch 41/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5554 - mae: 0.8439 - val_loss: 0.4397 - val_mae: 0.7089 - learning_rate: 0.0010
# Epoch 42/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5505 - mae: 0.8432 - val_loss: 0.4129 - val_mae: 0.6647 - learning_rate: 0.0010
# Epoch 43/120
# 180/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5580 - mae: 0.8470
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5580 - mae: 0.8469 - val_loss: 0.4054 - val_mae: 0.6427 - learning_rate: 0.0010
# Epoch 44/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5575 - mae: 0.8443 - val_loss: 0.3957 - val_mae: 0.6364 - learning_rate: 2.0000e-04
# Epoch 45/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5335 - mae: 0.8276 - val_loss: 0.3968 - val_mae: 0.6411 - learning_rate: 2.0000e-04
# Epoch 46/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5285 - mae: 0.8160 - val_loss: 0.3912 - val_mae: 0.6337 - learning_rate: 2.0000e-04
# Epoch 47/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5248 - mae: 0.8140 - val_loss: 0.3880 - val_mae: 0.6322 - learning_rate: 2.0000e-04
# Epoch 48/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5302 - mae: 0.8228 - val_loss: 0.3877 - val_mae: 0.6226 - learning_rate: 2.0000e-04
# Epoch 49/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5483 - mae: 0.8397 - val_loss: 0.3883 - val_mae: 0.6338 - learning_rate: 2.0000e-04
# Epoch 50/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5288 - mae: 0.8202 - val_loss: 0.3890 - val_mae: 0.6383 - learning_rate: 2.0000e-04
# Epoch 51/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5248 - mae: 0.8170 - val_loss: 0.3888 - val_mae: 0.6364 - learning_rate: 2.0000e-04
# Epoch 52/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5093 - mae: 0.8014 - val_loss: 0.3851 - val_mae: 0.6257 - learning_rate: 2.0000e-04
# Epoch 53/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5197 - mae: 0.8150 - val_loss: 0.3868 - val_mae: 0.6332 - learning_rate: 2.0000e-04
# Epoch 54/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5317 - mae: 0.8233 - val_loss: 0.3879 - val_mae: 0.6385 - learning_rate: 2.0000e-04
# Epoch 55/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5098 - mae: 0.7991 - val_loss: 0.3888 - val_mae: 0.6408 - learning_rate: 2.0000e-04
# Epoch 56/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5295 - mae: 0.8215 - val_loss: 0.3880 - val_mae: 0.6368 - learning_rate: 2.0000e-04
# Epoch 57/120
# 165/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5251 - mae: 0.8211
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5238 - mae: 0.8197 - val_loss: 0.3860 - val_mae: 0.6357 - learning_rate: 2.0000e-04
# Epoch 58/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5213 - mae: 0.8104 - val_loss: 0.3822 - val_mae: 0.6277 - learning_rate: 4.0000e-05
# Epoch 59/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5295 - mae: 0.8225 - val_loss: 0.3816 - val_mae: 0.6272 - learning_rate: 4.0000e-05
# Epoch 60/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5151 - mae: 0.8054 - val_loss: 0.3806 - val_mae: 0.6270 - learning_rate: 4.0000e-05
# Epoch 61/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5221 - mae: 0.8142 - val_loss: 0.3798 - val_mae: 0.6250 - learning_rate: 4.0000e-05
# Epoch 62/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4998 - mae: 0.7924 - val_loss: 0.3791 - val_mae: 0.6237 - learning_rate: 4.0000e-05
# Epoch 63/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5110 - mae: 0.8049 - val_loss: 0.3818 - val_mae: 0.6300 - learning_rate: 4.0000e-05
# Epoch 64/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5070 - mae: 0.7992 - val_loss: 0.3789 - val_mae: 0.6238 - learning_rate: 4.0000e-05
# Epoch 65/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5235 - mae: 0.8221 - val_loss: 0.3791 - val_mae: 0.6254 - learning_rate: 4.0000e-05
# Epoch 66/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5002 - mae: 0.7931 - val_loss: 0.3792 - val_mae: 0.6275 - learning_rate: 4.0000e-05
# Epoch 67/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5064 - mae: 0.7971 - val_loss: 0.3779 - val_mae: 0.6248 - learning_rate: 4.0000e-05
# Epoch 68/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5149 - mae: 0.8143 - val_loss: 0.3788 - val_mae: 0.6267 - learning_rate: 4.0000e-05
# Epoch 69/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5179 - mae: 0.8143 - val_loss: 0.3793 - val_mae: 0.6256 - learning_rate: 4.0000e-05
# Epoch 70/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5183 - mae: 0.8152 - val_loss: 0.3779 - val_mae: 0.6217 - learning_rate: 4.0000e-05
# Epoch 71/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5229 - mae: 0.8208 - val_loss: 0.3790 - val_mae: 0.6239 - learning_rate: 4.0000e-05
# Epoch 72/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5392 - mae: 0.8371 - val_loss: 0.3774 - val_mae: 0.6244 - learning_rate: 4.0000e-05
# Epoch 73/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5011 - mae: 0.7945 - val_loss: 0.3782 - val_mae: 0.6242 - learning_rate: 4.0000e-05
# Epoch 74/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5043 - mae: 0.7973 - val_loss: 0.3769 - val_mae: 0.6235 - learning_rate: 4.0000e-05
# Epoch 75/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5249 - mae: 0.8234 - val_loss: 0.3780 - val_mae: 0.6236 - learning_rate: 4.0000e-05
# Epoch 76/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5112 - mae: 0.8043 - val_loss: 0.3777 - val_mae: 0.6246 - learning_rate: 4.0000e-05
# Epoch 77/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5115 - mae: 0.8075 - val_loss: 0.3777 - val_mae: 0.6257 - learning_rate: 4.0000e-05
# Epoch 78/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5097 - mae: 0.8047 - val_loss: 0.3781 - val_mae: 0.6227 - learning_rate: 4.0000e-05
# Epoch 79/120
# 181/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5085 - mae: 0.8020
# Epoch 79: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5085 - mae: 0.8020 - val_loss: 0.3786 - val_mae: 0.6283 - learning_rate: 4.0000e-05
# Epoch 80/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5361 - mae: 0.8334 - val_loss: 0.3781 - val_mae: 0.6260 - learning_rate: 8.0000e-06
# Epoch 81/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5180 - mae: 0.8164 - val_loss: 0.3778 - val_mae: 0.6258 - learning_rate: 8.0000e-06
# Epoch 82/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5233 - mae: 0.8177 - val_loss: 0.3780 - val_mae: 0.6258 - learning_rate: 8.0000e-06
# Epoch 83/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5056 - mae: 0.7981 - val_loss: 0.3776 - val_mae: 0.6255 - learning_rate: 8.0000e-06
# Epoch 84/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5083 - mae: 0.8002 - val_loss: 0.3764 - val_mae: 0.6229 - learning_rate: 8.0000e-06
# Epoch 85/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5352 - mae: 0.8306 - val_loss: 0.3769 - val_mae: 0.6235 - learning_rate: 8.0000e-06
# Epoch 86/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5259 - mae: 0.8203 - val_loss: 0.3771 - val_mae: 0.6238 - learning_rate: 8.0000e-06
# Epoch 87/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5277 - mae: 0.8231 - val_loss: 0.3771 - val_mae: 0.6230 - learning_rate: 8.0000e-06
# Epoch 88/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5125 - mae: 0.8067 - val_loss: 0.3767 - val_mae: 0.6218 - learning_rate: 8.0000e-06
# Epoch 89/120
# 177/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4932 - mae: 0.7823
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4937 - mae: 0.7828 - val_loss: 0.3765 - val_mae: 0.6225 - learning_rate: 8.0000e-06
# Epoch 90/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4936 - mae: 0.7888 - val_loss: 0.3764 - val_mae: 0.6224 - learning_rate: 1.6000e-06
# Epoch 91/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5231 - mae: 0.8215 - val_loss: 0.3769 - val_mae: 0.6243 - learning_rate: 1.6000e-06
# Epoch 92/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5057 - mae: 0.7997 - val_loss: 0.3764 - val_mae: 0.6234 - learning_rate: 1.6000e-06
# Epoch 93/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5213 - mae: 0.8195 - val_loss: 0.3766 - val_mae: 0.6234 - learning_rate: 1.6000e-06
# Epoch 94/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5090 - mae: 0.8040 - val_loss: 0.3763 - val_mae: 0.6235 - learning_rate: 1.6000e-06
# Epoch 95/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5143 - mae: 0.8061 - val_loss: 0.3763 - val_mae: 0.6228 - learning_rate: 1.6000e-06
# Epoch 96/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5190 - mae: 0.8134 - val_loss: 0.3767 - val_mae: 0.6229 - learning_rate: 1.6000e-06
# Epoch 97/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5022 - mae: 0.7945 - val_loss: 0.3761 - val_mae: 0.6217 - learning_rate: 1.6000e-06
# Epoch 98/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4946 - mae: 0.7863 - val_loss: 0.3759 - val_mae: 0.6214 - learning_rate: 1.6000e-06
# Epoch 99/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5303 - mae: 0.8259 - val_loss: 0.3766 - val_mae: 0.6229 - learning_rate: 1.6000e-06
# Epoch 100/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5079 - mae: 0.8027 - val_loss: 0.3766 - val_mae: 0.6223 - learning_rate: 1.6000e-06
# Epoch 101/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5196 - mae: 0.8138 - val_loss: 0.3766 - val_mae: 0.6220 - learning_rate: 1.6000e-06
# Epoch 102/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5298 - mae: 0.8262 - val_loss: 0.3766 - val_mae: 0.6229 - learning_rate: 1.6000e-06
# Epoch 103/120
# 177/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5267 - mae: 0.8201
# Epoch 103: ReduceLROnPlateau reducing learning rate to 1e-06.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5262 - mae: 0.8195 - val_loss: 0.3765 - val_mae: 0.6225 - learning_rate: 1.6000e-06
# Epoch 104/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5174 - mae: 0.8120 - val_loss: 0.3769 - val_mae: 0.6233 - learning_rate: 1.0000e-06
# Epoch 105/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5097 - mae: 0.8024 - val_loss: 0.3764 - val_mae: 0.6227 - learning_rate: 1.0000e-06
# Epoch 106/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4997 - mae: 0.7916 - val_loss: 0.3764 - val_mae: 0.6231 - learning_rate: 1.0000e-06
# Epoch 107/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5193 - mae: 0.8132 - val_loss: 0.3767 - val_mae: 0.6242 - learning_rate: 1.0000e-06
# Epoch 108/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5161 - mae: 0.8114 - val_loss: 0.3764 - val_mae: 0.6235 - learning_rate: 1.0000e-06
# Epoch 109/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5354 - mae: 0.8354 - val_loss: 0.3767 - val_mae: 0.6234 - learning_rate: 1.0000e-06
# Epoch 110/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5019 - mae: 0.7946 - val_loss: 0.3767 - val_mae: 0.6237 - learning_rate: 1.0000e-06
# Epoch 111/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5256 - mae: 0.8223 - val_loss: 0.3768 - val_mae: 0.6231 - learning_rate: 1.0000e-06
# Epoch 112/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5144 - mae: 0.8087 - val_loss: 0.3765 - val_mae: 0.6218 - learning_rate: 1.0000e-06
# Epoch 113/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5183 - mae: 0.8104 - val_loss: 0.3763 - val_mae: 0.6218 - learning_rate: 1.0000e-06
# Epoch 113: early stopping
# Restoring model weights from the end of the best epoch: 98.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# Training Results:
# Mean Absolute Error: $4,794.24
# Root Mean Squared Error: $7,414.82
# R² Score: 0.5649

# %% [markdown]
# # Resultados - ELU
# ## Test 2
#
# Aumentando a divisão de dados para 32 e as epocas para 120, o desempenho foi um pouco superios ao teste 1, porem ainda é mais baixo do que com a ReLU
#
# - Funcao: Relu
# - Epocas: 120
# - Divisão dos dados: 50
# - Taxa de aprendizdo inicial (varia com as epocas): 0.001
# ---
#
# Erro médio absolute nas predições(`MAE`): $4,794.24
#
# Erro quadratico médio (`RMSE`): $7,414.82
#
# Coenficiente de determinação (`R² Score`): 0.5649
